# %%
import os

def build_depth_map(super_path):
    depth_map_path = {}

    # Walk through the directory tree
    for root, _, files in os.walk(super_path):
        for filename in files:
            if filename.endswith('.png'):
                full_path = os.path.join(root, filename)
                # Remove super_path from the full path to get the relative path
                relative_path = os.path.relpath(full_path, super_path)
                # Split the relative path into parts (folders)
                parts = relative_path.split(os.sep)
                parts[-1]=parts[-1][len('result_merged_depth_'):-len('.png')]
                
                # Initialize nested dictionaries as needed
                current_dict = depth_map_path
                for part in parts[:-1]:  # Iterate over all parts except the last one (filename)
                    current_dict = current_dict.setdefault(part, {})
                
                # Assign the full path to the deepest nested dictionary
                current_dict[parts[-1]] = full_path

    return depth_map_path

def build_depth_map_confidence(super_path):
    depth_map_path = {}

    # Walk through the directory tree
    for root, _, files in os.walk(super_path):
        for filename in files:
            if filename.endswith('.exr'):
                full_path = os.path.join(root, filename)
                # Remove super_path from the full path to get the relative path
                relative_path = os.path.relpath(full_path, super_path)
                # Split the relative path into parts (folders)
                parts = relative_path.split(os.sep)
                parts[-1]=parts[-1][len('result_merged_conf_'):-len('.exr')]
                
                # Initialize nested dictionaries as needed
                current_dict = depth_map_path
                for part in parts[:-1]:  # Iterate over all parts except the last one (filename)
                    current_dict = current_dict.setdefault(part, {})
                
                # Assign the full path to the deepest nested dictionary
                current_dict[parts[-1]] = full_path

    return depth_map_path

# %%
import os
from tqdm import tqdm

def find_train_folders(directory):
    train_folders = []
    for root, dirs, files in tqdm(os.walk(directory)):
        for dir in dirs:
            if dir.startswith('train'):
                train_folders.append(os.path.join(root, dir))
    return train_folders

train_path=find_train_folders('/mnt/Velocity Vault/Autofocus/Train/')
train_path=train_path[:2]
print("hell")

depth_map_path={}
depth_map_path_temp={}

for path in train_path:
    depth_map_path_temp=build_depth_map(path+"/merged_depth")
    depth_map_path.update(depth_map_path_temp)

depth_map_confidence_path={}
depth_map_confidence_path_temp={}

for path in train_path:
    depth_map_confidence_path_temp=build_depth_map_confidence(path+"/merged_conf")
    depth_map_confidence_path.update(depth_map_confidence_path_temp)




import pprint
pprint.pprint(depth_map_path)
pprint.pprint(depth_map_confidence_path)
# Out:
# 71904it [00:29, 2454.61it/s]
# hell
# {'apt1_0': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_0/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_0/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_0/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_0/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_0/result_merged_depth_top.png'},
#  'apt1_1': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_1/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_1/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_1/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_1/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_1/result_merged_depth_top.png'},
#  'apt1_2': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_2/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_2/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_2/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_2/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_2/result_merged_depth_top.png'},
#  'apt1_3': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_3/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_3/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_3/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_3/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_3/result_merged_depth_top.png'},
#  'apt1_4': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_4/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_4/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_4/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_4/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_4/result_merged_depth_top.png'},
#  'apt1_5': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_5/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_5/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_5/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_5/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_5/result_merged_depth_top.png'},
#  'apt1_6': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_6/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_6/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_6/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_6/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_6/result_merged_depth_top.png'},
#  'apt1_7': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_7/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_7/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_7/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_7/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_7/result_merged_depth_top.png'},
#  'apt1_8': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_8/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_8/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_8/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_8/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_8/result_merged_depth_top.png'},
#  'apt1_9': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_9/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt1_9/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt1_9/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt1_9/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt1_9/result_merged_depth_top.png'},
#  'apt2_0': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_0/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_0/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_0/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_0/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_0/result_merged_depth_top.png'},
#  'apt2_1': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_1/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_1/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_1/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_1/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_1/result_merged_depth_top.png'},
#  'apt2_2': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_2/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_2/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_2/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_2/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_2/result_merged_depth_top.png'},
#  'apt2_3': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_3/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_3/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_3/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_3/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_3/result_merged_depth_top.png'},
#  'apt2_4': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_4/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_4/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_4/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_4/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_4/result_merged_depth_top.png'},
#  'apt2_5': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_5/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_5/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_5/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_5/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_5/result_merged_depth_top.png'},
#  'apt2_6': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_6/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_6/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_6/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_6/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_6/result_merged_depth_top.png'},
#  'apt2_7': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_7/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_7/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_7/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_7/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_7/result_merged_depth_top.png'},
#  'apt2_8': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_8/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_8/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_8/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_8/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_8/result_merged_depth_top.png'},
#  'apt2_9': {'bottom': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_9/result_merged_depth_bottom.png',
#             'center': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/apt2_9/result_merged_depth_center.png',
#             'left': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/apt2_9/result_merged_depth_left.png',
#             'right': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/apt2_9/result_merged_depth_right.png',
#             'top': '/mnt/Velocity '
#                    'Vault/Autofocus/Train/train1/merged_depth/apt2_9/result_merged_depth_top.png'},
#  'books_0': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_0/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_0/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_0/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_0/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_0/result_merged_depth_top.png'},
#  'books_1': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_1/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_1/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_1/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_1/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_1/result_merged_depth_top.png'},
#  'books_2': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_2/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_2/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_2/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_2/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_2/result_merged_depth_top.png'},
#  'books_3': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_3/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_3/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_3/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_3/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_3/result_merged_depth_top.png'},
#  'books_4': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_4/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_4/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_4/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_4/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_4/result_merged_depth_top.png'},
#  'books_5': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_5/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_5/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_5/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_5/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_5/result_merged_depth_top.png'},
#  'books_6': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_6/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_6/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_6/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_6/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_6/result_merged_depth_top.png'},
#  'books_7': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_7/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_7/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_7/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_7/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_7/result_merged_depth_top.png'},
#  'books_8': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_8/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_8/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_8/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_8/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_8/result_merged_depth_top.png'},
#  'books_9': {'bottom': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_9/result_merged_depth_bottom.png',
#              'center': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/books_9/result_merged_depth_center.png',
#              'left': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train1/merged_depth/books_9/result_merged_depth_left.png',
#              'right': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/books_9/result_merged_depth_right.png',
#              'top': '/mnt/Velocity '
#                     'Vault/Autofocus/Train/train1/merged_depth/books_9/result_merged_depth_top.png'},
#  'bottles_0': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_0/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_0/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_0/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_0/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_0/result_merged_depth_top.png'},
#  'bottles_1': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_1/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_1/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_1/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_1/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_1/result_merged_depth_top.png'},
#  'bottles_2': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_2/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_2/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_2/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_2/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_2/result_merged_depth_top.png'},
#  'bottles_3': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_3/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_3/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_3/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_3/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_3/result_merged_depth_top.png'},
#  'bottles_4': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_4/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_4/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_4/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_4/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_4/result_merged_depth_top.png'},
#  'bottles_5': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_5/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_5/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_5/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_5/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_5/result_merged_depth_top.png'},
#  'bottles_6': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_6/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_6/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_6/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_6/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_6/result_merged_depth_top.png'},
#  'bottles_7': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_7/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_7/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_7/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_7/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_7/result_merged_depth_top.png'},
#  'bottles_8': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_8/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_8/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_8/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_8/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_8/result_merged_depth_top.png'},
#  'bottles_9': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_9/result_merged_depth_bottom.png',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train1/merged_depth/bottles_9/result_merged_depth_center.png',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train1/merged_depth/bottles_9/result_merged_depth_left.png',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train1/merged_depth/bottles_9/result_merged_depth_right.png',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train1/merged_depth/bottles_9/result_merged_depth_top.png'},
#  'campusoutdoors1_0': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_0/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_0/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_0/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_0/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_0/result_merged_depth_top.png'},
#  'campusoutdoors1_1': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_1/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_1/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_1/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_1/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_1/result_merged_depth_top.png'},
#  'campusoutdoors1_2': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_2/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_2/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_2/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_2/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_2/result_merged_depth_top.png'},
#  'campusoutdoors1_3': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_3/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_3/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_3/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_3/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_3/result_merged_depth_top.png'},
#  'campusoutdoors1_4': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_4/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_4/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_4/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_4/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_4/result_merged_depth_top.png'},
#  'campusoutdoors1_5': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_5/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_5/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_5/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_5/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_5/result_merged_depth_top.png'},
#  'campusoutdoors1_6': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_6/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_6/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_6/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_6/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_6/result_merged_depth_top.png'},
#  'campusoutdoors1_7': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_7/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_7/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_7/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_7/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_7/result_merged_depth_top.png'},
#  'campusoutdoors1_8': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_8/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_8/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_8/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_8/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_8/result_merged_depth_top.png'},
#  'campusoutdoors1_9': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_9/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_9/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_9/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_9/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train1/merged_depth/campusoutdoors1_9/result_merged_depth_top.png'},
#  'campusoutdoors2_0': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_0/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_0/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_0/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_0/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_0/result_merged_depth_top.png'},
#  'campusoutdoors2_1': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_1/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_1/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_1/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_1/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_1/result_merged_depth_top.png'},
#  'campusoutdoors2_2': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_2/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_2/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_2/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_2/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_2/result_merged_depth_top.png'},
#  'campusoutdoors2_3': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_3/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_3/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_3/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_3/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_3/result_merged_depth_top.png'},
#  'campusoutdoors2_4': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_4/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_4/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_4/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_4/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_4/result_merged_depth_top.png'},
#  'campusoutdoors2_5': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_5/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_5/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_5/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_5/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_5/result_merged_depth_top.png'},
#  'campusoutdoors2_6': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_6/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_6/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_6/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_6/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_6/result_merged_depth_top.png'},
#  'campusoutdoors2_7': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_7/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_7/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_7/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_7/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_7/result_merged_depth_top.png'},
#  'campusoutdoors2_8': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_8/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_8/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_8/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_8/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_8/result_merged_depth_top.png'},
#  'campusoutdoors2_9': {'bottom': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_9/result_merged_depth_bottom.png',
#                        'center': '/mnt/Velocity '
#                                  'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_9/result_merged_depth_center.png',
#                        'left': '/mnt/Velocity '
#                                'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_9/result_merged_depth_left.png',
#                        'right': '/mnt/Velocity '
#                                 'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_9/result_merged_depth_right.png',
#                        'top': '/mnt/Velocity '
#                               'Vault/Autofocus/Train/train2/merged_depth/campusoutdoors2_9/result_merged_depth_top.png'},
#  'fakeplants_0': {'bottom': '/mnt/Velocity '
#                             'Vault/Autofocus/Train/train2/merged_depth/fakeplants_0/result_merged_depth_bottom.png',
#                   'center': '/mnt/Velocity '
#                             'Vault/Autofocus/Train/train2/merged_depth/fakeplants_0/result_merged_depth_center.png',
#                   'left': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_depth/fakeplants_0/result_merged_depth_left.png',
#                   'right': '/mnt/Velocity '
#                            'Vault/Autofocus/Train/train2/merged_depth/fakeplants_0/result_merged_depth_right.png',
#                   'top': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_depth/fakeplants_0/result_merged_depth_top.png'},
#  'fakeplants_1': {'bottom': '/mnt/Velocity '
#                             'Vault/Autofocus/Train/train2/merged_depth/fakeplants_1/result_merged_depth_bottom.png',
#                   'center': '/mnt/Velocity '
#                             'Vault/Autofocus/Train/train2/merged_depth/fakeplants_1/result_merged_depth_center.png',
#                   'left': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_depth/fakeplants_1/result_merged_depth_left.png',
#                   'right': '/mnt/Velocity '
#                            'Vault/Autofocus/Train/train2/merged_depth/fakeplants_1/result_merged_depth_right.png',
#                   'top': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_depth/fakeplants_1/result_merged_depth_top.png'},
#  'fakeplants_2': {'bottom': '/mnt/Velocity '
#                             'Vault/Autofocus/Train/train2/merged_depth/fakeplants_2/result_merged_depth_bottom.png',
#                   'center': '/mnt/Velocity '
# ...
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage2_8/result_merged_conf_left.exr',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage2_8/result_merged_conf_right.exr',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage2_8/result_merged_conf_top.exr'},
#  'garage2_9': {'bottom': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/garage2_9/result_merged_conf_bottom.exr',
#                'center': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/garage2_9/result_merged_conf_center.exr',
#                'left': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage2_9/result_merged_conf_left.exr',
#                'right': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage2_9/result_merged_conf_right.exr',
#                'top': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage2_9/result_merged_conf_top.exr'},
#  'garage_0': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_0/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_0/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_0/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_0/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_0/result_merged_conf_top.exr'},
#  'garage_1': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_1/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_1/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_1/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_1/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_1/result_merged_conf_top.exr'},
#  'garage_2': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_2/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_2/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_2/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_2/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_2/result_merged_conf_top.exr'},
#  'garage_3': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_3/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_3/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_3/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_3/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_3/result_merged_conf_top.exr'},
#  'garage_4': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_4/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_4/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_4/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_4/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_4/result_merged_conf_top.exr'},
#  'garage_6': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_6/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_6/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_6/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_6/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_6/result_merged_conf_top.exr'},
#  'garage_7': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_7/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_7/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_7/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_7/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_7/result_merged_conf_top.exr'},
#  'garage_8': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_8/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_8/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_8/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_8/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_8/result_merged_conf_top.exr'},
#  'garage_9': {'bottom': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_9/result_merged_conf_bottom.exr',
#               'center': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/garage_9/result_merged_conf_center.exr',
#               'left': '/mnt/Velocity '
#                       'Vault/Autofocus/Train/train2/merged_conf/garage_9/result_merged_conf_left.exr',
#               'right': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/garage_9/result_merged_conf_right.exr',
#               'top': '/mnt/Velocity '
#                      'Vault/Autofocus/Train/train2/merged_conf/garage_9/result_merged_conf_top.exr'},
#  'hallway1_0': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_0/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_0/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_0/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_0/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_0/result_merged_conf_top.exr'},
#  'hallway1_2': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_2/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_2/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_2/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_2/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_2/result_merged_conf_top.exr'},
#  'hallway1_3': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_3/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_3/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_3/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_3/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_3/result_merged_conf_top.exr'},
#  'hallway1_4': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_4/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_4/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_4/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_4/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_4/result_merged_conf_top.exr'},
#  'hallway1_5': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_5/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_5/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_5/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_5/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_5/result_merged_conf_top.exr'},
#  'hallway1_6': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_6/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_6/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_6/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_6/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_6/result_merged_conf_top.exr'},
#  'hallway1_7': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_7/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_7/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_7/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_7/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_7/result_merged_conf_top.exr'},
#  'hallway1_8': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_8/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_8/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_8/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_8/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_8/result_merged_conf_top.exr'},
#  'hallway1_9': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_9/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway1_9/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway1_9/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway1_9/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway1_9/result_merged_conf_top.exr'},
#  'hallway2_0': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway2_0/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway2_0/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway2_0/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway2_0/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway2_0/result_merged_conf_top.exr'},
#  'hallway2_1': {'bottom': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway2_1/result_merged_conf_bottom.exr',
#                 'center': '/mnt/Velocity '
#                           'Vault/Autofocus/Train/train2/merged_conf/hallway2_1/result_merged_conf_center.exr',
#                 'left': '/mnt/Velocity '
#                         'Vault/Autofocus/Train/train2/merged_conf/hallway2_1/result_merged_conf_left.exr',
#                 'right': '/mnt/Velocity '
#                          'Vault/Autofocus/Train/train2/merged_conf/hallway2_1/result_merged_conf_right.exr',
#                 'top': '/mnt/Velocity '
#                        'Vault/Autofocus/Train/train2/merged_conf/hallway2_1/result_merged_conf_top.exr'}}

# %%
import numpy as np
import random


def generate_random_patches(size=(504,378)):
    image=np.zeros(size)
    patches=[]
    for _ in (range(100)):
        x=random.randint(16, 487)
        y=random.randint(16, 361)

        #print(x,y)
        
        breaker=False

        for i in range(x-26,x+26):
            for j in range(y-26,y+26):
                if i<0 or i>503 or j<0 or j>377 :
                    continue
                if image[i][j]==1:
                    breaker=True
                    break
            if breaker:
                break

        if breaker:
            continue
        
        x=x-16
        y=y-16

        for i in range(x,x+33):
            for j in range(y,y+33):
                image[i][j]=1

        patches.append((x,y))


    return patches

# %%
import numpy as np
import cv2
import OpenEXR
import Imath


def load_exr(file_path):
    exr_file = OpenEXR.InputFile(file_path)
    header = exr_file.header()
    dw = header['dataWindow']
    width = dw.max.x - dw.min.x + 1
    height = dw.max.y - dw.min.y + 1
    pt = Imath.PixelType(Imath.PixelType.FLOAT)
    r = np.frombuffer(exr_file.channel('R', pt), dtype=np.float32)
    r.shape = (height, width)
    return r

def predict_patches(depth_confidence_path):

    patch_threshold = 4

    depth_map_confidence = load_exr(depth_confidence_path)

    all_patches=generate_random_patches()

    confidence_patch_blocks=[depth_map_confidence[x:x+32,y:y+32] for (x,y) in all_patches]
    median_confidence_patch_block=[np.median(patch.flatten()) for patch in confidence_patch_blocks]

    patch_indices=[i for i, value in enumerate(median_confidence_patch_block) if value >= 0.98]

    if len(patch_indices)>4:
        patch_indices = sorted(range(len(median_confidence_patch_block)), key=lambda i: median_confidence_patch_block[i], reverse=True)[:patch_threshold]

    patches=[all_patches[patch_index] for patch_index in patch_indices]

    return patches

def predict_focal_length(depth_map_path,patch):
    depth_map = cv2.imread(depth_map_path, cv2.IMREAD_GRAYSCALE).astype(np.float32)

    depth_values=depth_map[patch[0]:patch[0]+32,patch[1]:patch[1]+32]
    depth_values=depth_values.flatten()

    # Define max and min values
    max_depth = 100.0
    min_depth = 0.2

    depth_map_in_meters = (max_depth * min_depth) / (max_depth - (max_depth - min_depth) * (depth_values / 255.0))

    # Compute the median value in the entire depth map
    median_depth = np.median(depth_map_in_meters)

    final_focus=median_depth*1000

    return final_focus

slice_focal_length=[3910.92,2289.27,1508.71,1185.83,935.91,801.09,700.37,605.39,546.23,486.87,447.99,407.40,379.91,350.41,329.95,307.54,291.72,274.13,261.53,247.35,237.08,225.41,216.88,207.10,198.18,191.60,183.96,178.29,171.69,165.57,160.99,155.61,150.59,146.81,142.35,138.98,134.99,131.23,127.69,124.99,121.77,118.73,116.40,113.63,110.99,108.47,106.54,104.23,102.01]

def find_closest(value, num_list):
    closest_value = min(num_list, key=lambda x: abs(x - value))
    return closest_value

def predict_slice(depth_map_path,depth_confidence_path):
    truth=[]

    patches=predict_patches(depth_confidence_path)
    
    for patch in patches:
        predicted_focus=predict_focal_length(depth_map_path,patch)
        closest_value = find_closest(predicted_focus, slice_focal_length)
        true_slice=slice_focal_length.index(closest_value)
        # manual annotation
        # true_slice=true_slice-1 if true_slice !=0 else true_slice
        truth.append((patch[0],patch[1],true_slice))

    return truth

# %%
from tqdm import tqdm
import copy

ground_truth=copy.deepcopy(depth_map_path)

for image_type in tqdm(ground_truth):
    for pos in ground_truth[image_type]:
        ground_truth[image_type][pos]=predict_slice(depth_map_path[image_type][pos],depth_map_confidence_path[image_type][pos])

import pprint
pprint.pprint(ground_truth)
# Out:
# 100%|██████████| 100/100 [00:12<00:00,  8.31it/s]
# {'apt1_0': {'bottom': [(66, 75, 4), (81, 16, 3), (357, 74, 7), (314, 51, 7)],
#             'center': [(461, 184, 9), (359, 308, 8), (3, 81, 0), (175, 210, 5)],
#             'left': [(8, 146, 0), (163, 286, 7), (125, 216, 6), (76, 125, 4)],
#             'right': [(266, 157, 5), (151, 57, 4), (371, 43, 6), (291, 277, 7)],
#             'top': [(407, 69, 6), (302, 164, 5), (159, 207, 6), (221, 167, 5)]},
#  'apt1_1': {'bottom': [(60, 6, 0), (213, 260, 3), (23, 105, 0), (158, 72, 1)],
#             'center': [(89, 246, 0),
#                        (261, 160, 3),
#                        (406, 107, 5),
#                          (438, 31, 6)],
#                'top': [(263, 206, 13)]},
#  'bottles_7': {'bottom': [(204, 65, 7),
#                           (299, 26, 6),
#                           (106, 128, 8),
#                           (86, 6, 9)],
#                'center': [(126, 183, 7),
#                           (175, 268, 7),
#                           (337, 63, 6),
#                           (219, 78, 7)],
#                'left': [(323, 132, 6),
#                         (337, 340, 7),
#                         (188, 290, 7),
#                         (370, 38, 6)],
#                'right': [(333, 148, 12),
#                          (443, 111, 7),
#                          (206, 14, 7),
#                          (191, 199, 7)],
#                'top': [(232, 142, 6),
#                        (301, 108, 5),
#                        (369, 43, 5),
#                        (424, 41, 6)]},
#  'bottles_8': {'bottom': [(16, 168, 0),
#                           (22, 108, 0),
#                           (15, 214, 0),
#                           (96, 138, 5)],
#                'center': [(273, 268, 9),
#                           (24, 159, 0),
#                           (308, 186, 10),
#                           (10, 10, 0)],
#                'left': [(174, 339, 8),
#                         (27, 338, 0),
#                         (257, 187, 8),
#                         (213, 193, 9)],
#                'right': [(248, 153, 7),
#                          (49, 294, 0),
#                          (3, 327, 0),
#                          (35, 193, 0)],
#                'top': [(286, 152, 8),
#                        (387, 216, 10),
#                        (30, 193, 0),
#                        (311, 87, 8)]},
#  'bottles_9': {'bottom': [(21, 53, 0)],
#                'center': [(41, 35, 0),
#                           (157, 89, 6),
#                           (331, 213, 18),
#                           (228, 37, 10)],
#                'left': [(386, 234, 18), (88, 126, 6), (47, 56, 0), (5, 56, 0)],
#                'right': [(49, 51, 0), (327, 120, 16)],
#                'top': [(397, 200, 15)]},
#  'campusoutdoors1_0': {'bottom': [(25, 168, 0),
#                                   (311, 111, 6),
#                                   (142, 62, 0),
#                                   (93, 92, 0)],
#                        'center': [(97, 179, 0),
#                                   (128, 77, 0),
#                                   (301, 298, 4),
#                                   (378, 118, 6)],
#                        'left': [(443, 204, 8),
#                                 (335, 38, 5),
#                                 (14, 250, 0),
#                                 (391, 194, 7)],
#                        'right': [(100, 143, 0),
#                                  (94, 254, 0),
#                                  (399, 283, 7),
#                                  (280, 45, 3)],
#                        'top': [(357, 309, 4),
#                                (112, 183, 1),
#                                (262, 70, 2),
#                                (357, 134, 5)]},
#  'campusoutdoors1_1': {'bottom': [(188, 208, 1),
#                                   (251, 24, 1),
#                                   (354, 158, 5),
#                                   (357, 259, 5)],
#                        'center': [(423, 299, 6),
#                                   (182, 201, 1),
#                                   (442, 119, 6),
#                                   (265, 211, 1)],
#                        'left': [(464, 331, 7),
#                                 (432, 278, 6),
#                                 (21, 283, 1),
#                                 (233, 87, 1)],
#                        'right': [(290, 162, 2),
#                                  (255, 263, 1),
#                                  (446, 148, 7),
#                                  (396, 0, 5)],
#                        'top': [(302, 199, 2),
#                                (268, 62, 1),
#                                (34, 278, 1),
#                                (188, 236, 1)]},
#  'campusoutdoors1_2': {'bottom': [(294, 24, 3),
#                                   (160, 221, 2),
#                                   (203, 264, 1),
#                                   (250, 345, 1)],
#                        'center': [(48, 200, 2),
#                                   (308, 36, 3),
#                                   (454, 74, 7),
#                                   (30, 108, 2)],
#                        'left': [(338, 151, 3),
#                                 (413, 299, 6),
#                                 (263, 308, 1),
#                                 (44, 104, 3)],
#                        'right': [(243, 193, 1),
#                                  (83, 182, 2),
#                                  (257, 51, 3),
#                                  (160, 256, 1)],
#                        'top': [(397, 315, 4),
#                                (77, 204, 2),
#                                (351, 56, 3),
#                                (390, 123, 4)]},
#  'campusoutdoors1_3': {'bottom': [(114, 316, 2),
#                                   (227, 201, 1),
#                                   (319, 223, 1),
#                                   (116, 93, 1)],
#                        'center': [(93, 113, 1),
#                                   (29, 10, 1),
#                                   (51, 287, 1),
#                                   (357, 84, 1)],
#                        'left': [(384, 311, 2),
#                                 (69, 259, 1),
#                                 (248, 6, 1),
#                                 (350, 135, 1)],
#                        'right': [(200, 153, 1),
#                                  (100, 23, 1),
#                                  (414, 249, 2),
#                                  (223, 201, 1)],
#                        'top': [(42, 114, 2),
#                                (93, 318, 1),
#                                (220, 327, 0),
#                                (246, 35, 1)]},
#  'campusoutdoors1_4': {'bottom': [(329, 282, 8),
#                                   (128, 69, 4),
#                                   (23, 96, 4),
#                                   (279, 328, 5)],
#                        'center': [(405, 184, 8),
#                                   (331, 169, 6),
#                                   (315, 47, 6),
#                                   (130, 259, 1)],
#                        'left': [(393, 134, 9),
#                                 (57, 76, 4),
#                                 (167, 299, 1),
#                                 (330, 123, 7)],
#                        'right': [(109, 168, 1),
#                                  (181, 304, 1),
#                                  (283, 203, 4),
#                                  (334, 17, 7)],
#                        'top': [(351, 142, 6),
#                                (183, 295, 1),
#                                (193, 238, 1),
#                                (465, 178, 8)]},
#  'campusoutdoors1_5': {'bottom': [(272, 160, 4),
#                                   (10, 301, 0),
#                                   (149, 91, 1),
#                                   (227, 52, 1)],
#                        'center': [(377, 199, 4),
#                                   (120, 202, 3),
#                                   (200, 70, 1),
#                                   (218, 213, 3)],
#                        'left': [(59, 247, 0),
#                                 (368, 225, 4),
#                                 (10, 243, 0),
#                                 (287, 17, 1)],
#                        'right': [(403, 221, 4),
#                                  (188, 111, 1),
#                                  (221, 266, 3),
#                                  (158, 265, 3)],
#                        'top': [(359, 183, 3),
#                                (55, 310, 0),
#                                (416, 85, 5),
#                                (341, 238, 3)]},
#  'campusoutdoors1_6': {'bottom': [(275, 140, 3),
#                                   (339, 164, 7),
#                                   (382, 75, 9),
#                                   (343, 296, 7)],
#                        'center': [(412, 132, 8),
#                                   (366, 255, 6),
#                                   (306, 262, 4),
#                                   (426, 40, 8)],
#                        'left': [(311, 244, 4),
#                                 (422, 132, 8),
#                                 (441, 336, 8),
#                                 (345, 169, 5)],
#                        'right': [(341, 203, 5),
#                                  (247, 141, 2),
#                                  (333, 294, 4),
#                                  (165, 295, 4)],
#                        'top': [(156, 208, 3),
#                                (238, 294, 3),
#                                (464, 180, 8),
#                                (289, 292, 3)]},
#  'campusoutdoors1_7': {'bottom': [(344, 172, 9),
#                                   (338, 281, 8),
#                                   (314, 324, 6),
#                                   (19, 306, 5)],
#                        'center': [(414, 173, 9),
#                                   (416, 128, 9),
#                                   (399, 313, 8),
#                                   (197, 126, 16)],
#                        'left': [(262, 315, 19),
#                                 (66, 295, 5),
#                                 (364, 246, 8),
#                                 (448, 324, 10)],
#                        'right': [(431, 167, 9),
#                                  (168, 46, 14),
#                                  (189, 141, 16),
#                                  (400, 58, 8)],
#                        'top': [(461, 236, 8),
#                                (350, 304, 5),
#                                (461, 166, 8),
#                                (120, 256, 4)]},
#  'campusoutdoors1_8': {'bottom': [(383, 224, 6),
#                                   (150, 15, 1),
#                                   (321, 130, 2),
#                                   (95, 180, 0)],
#                        'center': [(256, 272, 0),
#                                   (308, 109, 1),
#                                   (237, 25, 1),
#                                   (177, 298, 0)],
#                        'left': [(380, 289, 4),
#                                 (254, 264, 0),
#                                 (266, 102, 1),
#                                 (90, 233, 0)],
#                        'right': [(349, 307, 3),
#                                  (110, 147, 0),
#                                  (402, 178, 5),
#                                  (209, 88, 0)],
#                        'top': [(117, 262, 0),
#                                (412, 176, 4),
#                                (233, 241, 0),
#                                (260, 338, 0)]},
#  'campusoutdoors1_9': {'bottom': [(217, 324, 0),
#                                   (95, 30, 0),
#                                   (61, 81, 0),
#                                   (415, 174, 1)],
#                        'center': [(144, 303, 0),
#                                   (280, 211, 0),
#                                   (333, 313, 0),
#                                   (39, 162, 0)],
#                        'left': [(386, 339, 2),
#                                 (226, 60, 0),
#                                 (129, 289, 0),
#                                 (426, 266, 1)],
#                        'right': [(283, 249, 0),
#                                  (119, 285, 0),
#                                  (357, 218, 0),
#                                  (194, 201, 0)],
#                        'top': [(21, 259, 0),
#                                (429, 313, 2),
#                                (122, 50, 0),
#                                (149, 217, 0)]},
#  'campusoutdoors2_0': {'bottom': [(74, 174, 0),
#                                   (370, 147, 8),
#                                   (249, 34, 1),
#                                   (207, 131, 1)],
#                        'center': [(246, 69, 1),
#                                   (217, 235, 0),
#                                   (197, 45, 1),
#                                   (229, 131, 1)],
#                        'left': [(153, 244, 0),
#                                 (319, 147, 3),
#                                 (242, 66, 1),
#                                 (31, 153, 0)],
#                        'right': [(73, 300, 0),
#                                  (54, 224, 0),
#                                  (318, 87, 3),
#                                  (218, 39, 1)],
#                        'top': [(272, 35, 1),
#                                (259, 139, 1),
#                                (379, 136, 5),
#                                (73, 101, 0)]},
#  'campusoutdoors2_1': {'bottom': [(284, 228, 13),
#                                   (178, 18, 11),
#                                   (131, 37, 10),
#                                   (266, 74, 12)],
#                        'center': [(399, 132, 12),
#                                   (96, 264, 9),
#                                   (319, 77, 11),
#                                   (342, 156, 11)],
#                        'left': [(289, 139, 11),
#                                 (360, 277, 12),
#                                 (388, 97, 13),
#                                 (67, 308, 9)],
#                        'right': [(245, 20, 9),
#                                  (123, 235, 9),
#                                  (345, 175, 11),
#                                  (413, 6, 12)],
#                        'top': [(417, 192, 10),
#                                (241, 12, 8),
#                                (109, 151, 7),
#                                (160, 220, 8)]},
#  'campusoutdoors2_2': {'bottom': [(266, 140, 18),
#                                   (236, 44, 16),
#                                   (218, 100, 16),
#                                   (328, 137, 22)],
#                        'center': [(277, 160, 14),
#                                   (440, 104, 18),
#                                   (225, 132, 4),
#                                   (142, 122, 4),
#                                   (159, 79, 3)],
#                        'left': [(243, 67, 2),
#                                 (140, 345, 0),
#                                 (19, 90, 5),
#                                 (95, 197, 4)],
#                        'right': [(220, 20, 1),
#                                  (309, 274, 4),
#                                  (322, 109, 4),
#                                  (61, 208, 4)],
#                        'top': [(449, 69, 4),
#                                (112, 143, 4),
#                                (375, 106, 4),
#                                (49, 192, 5)]},
#  'campusoutdoors2_8': {'bottom': [(67, 62, 4),
#                                   (120, 242, 5),
#                                   (26, 234, 6),
#                                   (279, 329, 3)],
#                        'center': [(410, 91, 1),
#                                   (453, 116, 3),
#                                   (359, 43, 4),
#                                   (85, 25, 4)],
#                        'left': [(361, 85, 4),
#                                 (136, 148, 4),
#                                 (444, 301, 4),
#                                 (319, 309, 3)],
#                        'right': [(126, 105, 4),
#                                  (43, 18, 4),
#                                  (433, 290, 4),
#                                  (417, 247, 3)],
#                        'top': [(320, 288, 3),
#                                (163, 243, 5),
#                                (60, 35, 4),
#                                (211, 176, 4)]},
#  'campusoutdoors2_9': {'bottom': [(337, 178, 4),
#                                   (79, 84, 6),
#                                   (179, 117, 5),
#                                   (326, 249, 3)],
#                        'center': [(179, 125, 5),
#                                   (376, 50, 4),
#                                   (446, 43, 4),
#                                   (442, 324, 1)],
#                        'left': [(275, 208, 3),
#                                 (214, 252, 5),
#                                 (439, 200, 4),
#                                 (151, 341, 5)],
#                        'right': [(169, 96, 5),
#                                  (186, 247, 4),
#                                  (296, 316, 0),
#                                  (330, 272, 0)],
#                        'top': [(451, 227, 4),
#                                (417, 99, 4),
#                                (302, 333, 0),
#                                (356, 174, 3)]},
#  'fakeplants_0': {'bottom': [(193, 172, 4),
#                              (370, 42, 3),
#                              (323, 50, 1),
#                              (244, 276, 6)],
#                   'center': [(256, 252, 5),
#                              (325, 259, 5),
#                              (449, 84, 3),
#                              (392, 259, 3)],
#                   'left': [(232, 114, 5),
#                            (169, 319, 6),
#                            (421, 294, 3),
#                            (358, 154, 4)],
#                   'right': [(330, 143, 4),
#                             (119, 218, 5),
#                             (265, 111, 4),
#                             (415, 1, 3)],
#                   'top': [(427, 69, 3),
#                           (349, 199, 4),
#                           (410, 198, 3),
#                           (188, 102, 5)]},
#  'fakeplants_1': {'bottom': [(270, 22, 2),
#                              (252, 68, 2),
#                              (375, 157, 3),
#                              (390, 211, 3)],
#                   'center': [(275, 72, 2),
#                              (94, 302, 3),
#                              (348, 152, 2),
#                              (37, 306, 3)],
#                   'left': [(338, 238, 3),
#                            (79, 240, 4),
#                            (364, 172, 3),
#                            (41, 305, 4)],
#                   'right': [(230, 276, 3),
#                             (46, 289, 3),
#                             (391, 134, 3),
#                             (168, 3, 2)],
#                   'top': [(96, 19, 2),
#                           (398, 212, 3),
#                           (363, 82, 2),
#                           (384, 165, 3)]},
#  'fakeplants_2': {'bottom': [(410, 43, 2),
#                              (319, 155, 2),
#                              (119, 335, 1),
#                              (408, 108, 2)],
#                   'center': [(418, 63, 1),
#                              (229, 278, 2),
#                              (62, 33, 2),
#                              (17, 225, 0)],
#                   'left': [(352, 80, 1),
#                            (373, 278, 2),
#                            (40, 40, 2),
#                            (310, 111, 2)],
#                   'right': [(344, 186, 2),
#                             (347, 284, 1),
#                             (22, 273, 2),
#                             (93, 268, 1)],
#                   'top': [(234, 240, 2),
#                           (282, 56, 2),
#                           (427, 277, 1),
#                           (469, 94, 2)]},
#  'fakeplants_3': {'bottom': [(335, 145, 2),
#                              (411, 41, 3),
#                              (360, 267, 2),
#                              (432, 158, 3)],
#                   'center': [(384, 234, 1),
#                              (430, 146, 2),
#                              (395, 40, 2),
#                              (179, 183, 7)],
#                   'left': [(457, 82, 3),
#                            (36, 113, 2),
#                            (348, 143, 2),
#                            (168, 220, 7)],
#                   'right': [(448, 117, 2),
#                             (442, 61, 2),
#                             (361, 195, 1),
#                             (425, 230, 2)],
#                   'top': [(454, 120, 2),
#                           (384, 239, 2),
#                           (211, 111, 7),
#                           (389, 48, 2)]},
#  'fakeplants_4': {'bottom': [(432, 226, 4), (435, 87, 4)],
#                   'center': [(353, 278, 3),
#                              (260, 334, 3),
#                              (215, 18, 4),
#                              (137, 37, 4)],
#                   'left': [(193, 56, 4), (467, 280, 3), (425, 221, 4)],
#                   'right': [],
#                   'top': [(266, 322, 2), (461, 207, 3)]},
#  'fakeplants_5': {'bottom': [(29, 224, 2),
#                              (5, 66, 1),
#                              (320, 189, 2),
#                              (82, 67, 4)],
#                   'center': [(328, 47, 2),
#                              (147, 39, 2),
#                              (292, 327, 2),
#                              (164, 263, 2)],
#                   'left': [(395, 280, 3),
#                            (42, 161, 2),
#                            (125, 333, 2),
#                            (227, 132, 4)],
#                   'right': [(191, 215, 1),
#                             (331, 78, 2),
#                             (107, 258, 2),
#                             (178, 259, 2)],
#                   'top': [(264, 50, 3),
#                           (114, 157, 2),
# ...
#                           (251, 9, 0),
#                           (309, 53, 0),
#                           (426, 91, 2)],
#                'center': [(283, 7, 0),
#                           (220, 20, 0),
#                           (307, 174, 13),
#                           (100, 87, 8)],
#                'left': [(189, 22, 0), (352, 28, 0), (89, 10, 0), (262, 5, 0)],
#                'right': [(365, 31, 0),
#                          (287, 107, 12),
#                          (245, 88, 13),
#                          (292, 37, 0)],
#                'top': [(451, 101, 2),
#                        (184, 123, 7),
#                        (338, 30, 0),
#                        (355, 148, 11)]},
#  'garage2_6': {'bottom': [(126, 191, 6),
#                           (254, 126, 6),
#                           (175, 173, 6),
#                           (25, 86, 6)],
#                'center': [(194, 146, 6),
#                           (264, 132, 6),
#                           (188, 53, 12),
#                           (167, 194, 6)],
#                'left': [(421, 221, 13),
#                         (272, 162, 6),
#                         (307, 336, 11),
#                         (358, 245, 11)],
#                'right': [(371, 20, 9), (210, 85, 6), (150, 97, 6), (95, 15, 6)],
#                'top': [(249, 49, 6),
#                        (195, 208, 5),
#                        (159, 65, 6),
#                        (364, 270, 9)]},
#  'garage2_7': {'bottom': [(180, 334, 1),
#                           (233, 212, 2),
#                           (309, 305, 3),
#                           (266, 288, 2)],
#                'center': [(193, 308, 1),
#                           (127, 326, 0),
#                           (239, 229, 2),
#                           (391, 149, 8)],
#                'left': [(207, 190, 2),
#                         (289, 262, 2),
#                         (318, 306, 3),
#                         (341, 129, 11)],
#                'right': [(220, 242, 2),
#                          (246, 187, 1),
#                          (187, 287, 1),
#                          (307, 38, 10)],
#                'top': [(336, 235, 2),
#                        (234, 178, 1),
#                        (308, 189, 2),
#                        (294, 327, 2)]},
#  'garage2_8': {'bottom': [(277, 322, 2),
#                           (345, 73, 4),
#                           (112, 207, 0),
#                           (123, 112, 0)],
#                'center': [(329, 203, 2),
#                           (38, 67, 0),
#                           (214, 149, 3),
#                           (348, 152, 4)],
#                'left': [(12, 72, 0),
#                         (390, 156, 4),
#                         (331, 211, 2),
#                         (259, 166, 3)],
#                'right': [(34, 56, 0),
#                          (89, 144, 0),
#                          (275, 68, 4),
#                          (235, 243, 2)],
#                'top': [(424, 207, 2),
#                        (372, 256, 2),
#                        (122, 8, 0),
#                        (175, 55, 0)]},
#  'garage2_9': {'bottom': [(96, 85, 4),
#                           (49, 19, 5),
#                           (51, 208, 6),
#                           (308, 144, 8)],
#                'center': [(359, 151, 7),
#                           (431, 97, 4),
#                           (177, 161, 3),
#                           (155, 117, 4)],
#                'left': [(459, 46, 4),
#                         (253, 221, 7),
#                         (145, 126, 4),
#                         (62, 299, 6)],
#                'right': [(390, 51, 5), (74, 25, 4), (318, 7, 6), (64, 165, 4)],
#                'top': [(435, 128, 7),
#                        (168, 263, 6),
#                        (333, 71, 6),
#                        (215, 160, 3)]},
#  'garage_0': {'bottom': [(12, 104, 6), (12, 47, 6)],
#               'center': [(13, 166, 3),
#                          (62, 199, 6),
#                          (158, 252, 6),
#                          (109, 96, 5)],
#               'left': [(201, 90, 5), (43, 300, 6), (53, 208, 6), (84, 31, 5)],
#               'right': [(61, 287, 6), (51, 154, 5), (64, 82, 5), (193, 243, 5)],
#               'top': [(100, 271, 5),
#                       (204, 143, 5),
#                       (212, 31, 4),
#                       (142, 27, 5)]},
#  'garage_1': {'bottom': [(2, 98, 2)],
#               'center': [(41, 62, 2), (9, 164, 1), (60, 133, 2)],
#               'left': [(25, 162, 2), (54, 3, 2), (38, 97, 2)],
#               'right': [(13, 142, 1), (66, 143, 4), (66, 34, 2)],
#               'top': [(26, 168, 1), (61, 22, 2), (56, 118, 2)]},
#  'garage_2': {'bottom': [],
#               'center': [(439, 64, 7), (102, 82, 8), (77, 20, 3), (34, 36, 3)],
#               'left': [(314, 102, 8), (352, 4, 3), (135, 111, 9)],
#               'right': [(174, 68, 8), (115, 28, 4), (444, 5, 4), (247, 10, 3)],
#               'top': []},
#  'garage_3': {'bottom': [(93, 61, 5),
#                          (231, 94, 4),
#                          (284, 91, 4),
#                          (265, 149, 3)],
#               'center': [(187, 113, 3),
#                          (360, 70, 4),
#                          (266, 81, 4),
#                          (246, 280, 16)],
#               'left': [(324, 110, 4),
#                        (261, 105, 4),
#                        (206, 92, 4),
#                        (387, 102, 4)],
#               'right': [(179, 57, 4),
#                         (196, 181, 15),
#                         (50, 105, 3),
#                         (302, 73, 4)],
#               'top': [(204, 142, 2),
#                       (418, 240, 13),
#                       (180, 72, 4),
#                       (333, 267, 14)]},
#  'garage_4': {'bottom': [(316, 62, 9),
#                          (321, 191, 9),
#                          (372, 288, 9),
#                          (117, 47, 3)],
#               'center': [(296, 93, 7),
#                          (337, 281, 7),
#                          (444, 214, 9),
#                          (357, 164, 8)],
#               'left': [(442, 80, 10),
#                        (77, 38, 2),
#                        (403, 227, 9),
#                        (104, 110, 3)],
#               'right': [(194, 97, 13),
#                         (251, 38, 6),
#                         (126, 47, 3),
#                         (424, 111, 9)],
#               'top': [(310, 229, 13),
#                       (159, 87, 3),
#                       (361, 65, 7),
#                       (261, 253, 10)]},
#  'garage_6': {'bottom': [(401, 260, 4),
#                          (329, 106, 3),
#                          (277, 121, 2),
#                          (419, 206, 4)],
#               'center': [(192, 127, 6),
#                          (395, 246, 3),
#                          (349, 30, 5),
#                          (148, 80, 5)],
#               'left': [(384, 114, 3),
#                        (362, 267, 3),
#                        (442, 334, 4),
#                        (431, 62, 4)],
#               'right': [(225, 70, 6),
#                         (435, 30, 4),
#                         (401, 187, 3),
#                         (444, 213, 4)],
#               'top': [(285, 147, 2),
#                       (390, 74, 3),
#                       (405, 179, 3),
#                       (452, 178, 4)]},
#  'garage_7': {'bottom': [(9, 135, 2),
#                          (126, 205, 5),
#                          (172, 102, 3),
#                          (34, 24, 1)],
#               'center': [(87, 93, 2),
#                          (172, 116, 3),
#                          (86, 174, 1),
#                          (185, 64, 2)],
#               'left': [(47, 213, 1), (309, 42, 2), (2, 163, 2), (74, 83, 2)],
#               'right': [(25, 14, 1), (90, 24, 1), (340, 116, 18), (267, 15, 2)],
#               'top': [(102, 117, 2), (296, 41, 2), (238, 90, 2), (320, 94, 4)]},
#  'garage_8': {'bottom': [(148, 314, 9),
#                          (158, 122, 15),
#                          (167, 220, 12),
#                          (245, 298, 9)],
#               'center': [(260, 190, 11),
#                          (117, 213, 11),
#                          (444, 294, 7),
#                          (89, 265, 9)],
#               'left': [(192, 285, 10),
#                        (244, 339, 9),
#                        (248, 144, 15),
#                        (329, 289, 10)],
#               'right': [(314, 29, 13),
#                         (287, 103, 11),
#                         (206, 56, 13),
#                         (133, 217, 9)],
#               'top': [(376, 193, 9),
#                       (172, 300, 8),
#                       (314, 149, 11),
#                       (227, 159, 11)]},
#  'garage_9': {'bottom': [(291, 304, 0),
#                          (25, 292, 0),
#                          (87, 83, 0),
#                          (155, 197, 1)],
#               'center': [(366, 274, 1),
#                          (363, 39, 0),
#                          (160, 137, 1),
#                          (169, 219, 1)],
#               'left': [(320, 94, 1),
#                        (314, 302, 0),
#                        (146, 21, 1),
#                        (152, 104, 1)],
#               'right': [(338, 26, 0),
#                         (211, 215, 1),
#                         (356, 325, 0),
#                         (233, 290, 0)],
#               'top': [(46, 220, 0), (380, 267, 1), (234, 56, 1), (302, 85, 1)]},
#  'hallway1_0': {'bottom': [(394, 183, 8),
#                            (102, 337, 4),
#                            (366, 32, 12),
#                            (287, 277, 6)],
#                 'center': [(324, 110, 9),
#                            (451, 200, 6),
#                            (215, 254, 6),
#                            (373, 74, 10)],
#                 'left': [(311, 316, 4),
#                          (368, 309, 4),
#                          (291, 239, 7),
#                          (46, 221, 8)],
#                 'right': [(59, 247, 6),
#                           (50, 21, 11),
#                           (200, 16, 10),
#                           (341, 163, 7)],
#                 'top': [(385, 110, 8),
#                         (280, 335, 3),
#                         (168, 57, 10),
#                         (350, 333, 3)]},
#  'hallway1_2': {'bottom': [],
#                 'center': [(365, 268, 8),
#                            (286, 186, 9),
#                            (348, 202, 8),
#                            (268, 266, 14)],
#                 'left': [],
#                 'right': [(225, 128, 10)],
#                 'top': []},
#  'hallway1_3': {'bottom': [(38, 12, 3), (94, 36, 7), (332, 71, 8)],
#                 'center': [(407, 73, 7),
#                            (201, 94, 6),
#                            (44, 159, 3),
#                            (332, 214, 17)],
#                 'left': [(15, 12, 1),
#                          (429, 122, 8),
#                          (203, 143, 7),
#                          (58, 39, 3)],
#                 'right': [(375, 8, 7), (207, 42, 6), (46, 145, 3), (15, 8, 1)],
#                 'top': [(94, 170, 3),
#                         (117, 8, 2),
#                         (72, 108, 3),
#                         (464, 125, 8)]},
#  'hallway1_4': {'bottom': [(12, 224, 3),
#                            (76, 310, 5),
#                            (102, 240, 9),
#                            (6, 313, 4)],
#                 'center': [(186, 243, 8),
#                            (259, 103, 8),
#                            (230, 25, 4),
#                            (108, 162, 3)],
#                 'left': [(172, 272, 8),
#                          (236, 54, 5),
#                          (41, 318, 4),
#                          (125, 168, 3)],
#                 'right': [(160, 139, 5),
#                           (244, 115, 8),
#                           (105, 19, 3),
#                           (85, 257, 4)],
#                 'top': [(146, 189, 4),
#                         (189, 144, 3),
#                         (322, 120, 7),
#                         (219, 56, 4)]},
#  'hallway1_5': {'bottom': [(104, 140, 2),
#                            (202, 73, 3),
#                            (175, 186, 3),
#                            (231, 184, 4)],
#                 'center': [(301, 148, 3),
#                            (138, 81, 3),
#                            (274, 329, 3),
#                            (219, 135, 3)],
#                 'left': [(357, 205, 3),
#                          (211, 316, 3),
#                          (258, 286, 3),
#                          (142, 42, 2)],
#                 'right': [(316, 257, 3),
#                           (125, 108, 2),
#                           (239, 68, 3),
#                           (359, 192, 3)],
#                 'top': [(172, 53, 2),
#                         (303, 281, 3),
#                         (300, 232, 3),
#                         (176, 140, 2)]},
#  'hallway1_6': {'bottom': [(55, 72, 0),
#                            (176, 13, 0),
#                            (221, 33, 0),
#                            (110, 97, 0)],
#                 'center': [(95, 32, 0),
#                            (5, 141, 0),
#                            (100, 94, 0),
#                            (381, 294, 9)],
#                 'left': [(58, 336, 0),
#                          (237, 279, 9),
#                          (442, 114, 7),
#                          (376, 1, 1)],
#                 'right': [(33, 256, 1),
#                           (177, 5, 0),
#                           (252, 180, 8),
#                           (49, 188, 0)],
#                 'top': [(309, 11, 0),
#                         (64, 21, 0),
#                         (406, 206, 8),
#                         (110, 95, 0)]},
#  'hallway1_7': {'bottom': [(315, 47, 16),
#                            (253, 59, 13),
#                            (328, 102, 16),
#                            (126, 32, 12)],
#                 'center': [(364, 170, 16),
#                            (406, 46, 13),
#                            (195, 85, 11),
#                            (347, 221, 17)],
#                 'left': [(420, 173, 15),
#                          (227, 138, 13),
#                          (439, 116, 15),
#                          (286, 118, 13)],
#                 'right': [(201, 10, 10),
#                           (390, 105, 15),
#                           (93, 32, 9),
#                           (416, 38, 13)],
#                 'top': [(171, 82, 8),
#                         (367, 201, 13),
#                         (314, 181, 11),
#                         (346, 91, 10)]},
#  'hallway1_8': {'bottom': [(140, 18, 13)],
#                 'center': [(259, 145, 15),
#                            (405, 102, 16),
#                            (389, 159, 16),
#                            (226, 43, 11)],
#                 'left': [(376, 268, 17), (423, 279, 18)],
#                 'right': [(338, 1, 13),
#                           (339, 61, 13),
#                           (388, 15, 15),
#                           (228, 39, 13)],
#                 'top': [(427, 157, 13),
#                         (456, 210, 13),
#                         (373, 93, 11),
#                         (348, 168, 13)]},
#  'hallway1_9': {'bottom': [],
#                 'center': [(84, 55, 8), (24, 233, 7)],
#                 'left': [],
#                 'right': [],
#                 'top': []},
#  'hallway2_0': {'bottom': [(174, 282, 5),
#                            (223, 279, 5),
#                            (7, 22, 5),
#                            (202, 228, 4)],
#                 'center': [(202, 262, 4),
#                            (213, 47, 12),
#                            (356, 79, 12),
#                            (280, 99, 12)],
#                 'left': [(83, 29, 5),
#                          (307, 122, 13),
#                          (434, 154, 13),
#                          (256, 151, 13)],
#                 'right': [(210, 285, 5),
#                           (258, 119, 9),
#                           (403, 46, 11),
#                           (292, 26, 11)],
#                 'top': [(306, 100, 11),
#                         (359, 78, 11),
#                         (431, 76, 10),
#                         (292, 158, 9)]},
#  'hallway2_1': {'bottom': [],
#                 'center': [(438, 319, 9), (371, 306, 8)],
#                 'left': [],
#                 'right': [(373, 266, 8)],
#                 'top': [(459, 270, 8)]}}

# %%
patch_count=[]

for key1 in ground_truth:
    for key2 in ground_truth[key1]:
        patch_count.append(len(ground_truth[key1][key2]))

print(min(patch_count)," ",np.mean(patch_count)," ",max(patch_count))
# Out:
# 0   3.774   4

# %%
import cv2

def resize_image_by_factor(image, factor=4):    # Get the dimensions of the image
    height, width = image.shape[:2]

    # Calculate new dimensions
    new_width = width // factor
    new_height = height // factor

    # Resize the image
    resized_image = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)
    
    return resized_image

# %%
super_path='/mnt/Velocity Vault/Autofocus/Train/train2/'
image_type='fakeplants_2/'
pat=1

# %%
import cv2
import numpy as np

def most_focused_image_index(images):
    max_variance = -1
    focused_index = -1
    
    for i, img in enumerate(images):
        # Convert to grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        # Compute the Laplacian of the image
        laplacian = cv2.Laplacian(gray, cv2.CV_64F)
        print(gray.shape)
        
        # Calculate the variance of the Laplacian
        variance = laplacian.var()
        
        # Update the most focused image index if the current one is more focused
        if variance > max_variance:
            max_variance = variance
            focused_index = i
    
    return focused_index

# Example usage:
# Assuming images is a list of 49 images with each image being a numpy array of size (128, 128, 3)
# focused_image_index = most_focused_image_index(images)

# %%
import os
import cv2

# Directory path where images are stored
path=super_path+'scaled_images/'+image_type

# Filename pattern to filter
filename_pattern = 'result_scaled_image_center.jpg'

# Initialize an empty list to store images
images = []

# Recursively traverse the directory tree
for root, _, files in os.walk(path):
    for filename in files:
        if filename == filename_pattern:
            # Construct the full file path
            file_path = os.path.join(root, filename)
            
            # Open the image using PIL (assuming PNG format)
            image = cv2.imread(file_path)
            
            #  the image to the list
            images.append(image)


# Now 'images' contains all images named 'result_up_pd_left_center.png' from the directory and its subfolders
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have 49 images stored in a list called images
# Each image in images should be a numpy array or a PIL Image object

# Example list of 49 images (using placeholder numpy arrays)
#images = [np.random.random((100, 100)) for _ in range(49)]

# Determine layout of subplots (7x7 grid for 49 images)
num_images = len(images)
rows = 1
cols = 7

from operator import truth
import numpy as np
import matplotlib.pyplot as plt
import cv2

truth_slice=ground_truth[image_type[:-1]]['center'][pat][2]
patch=(ground_truth[image_type[:-1]]['center'][pat][0],ground_truth[image_type[:-1]]['center'][pat][1])
print(truth_slice)
print(patch)
print(images[0].shape)
images=[im[patch[0]:patch[0]+32,patch[1]:patch[1]+32] for im in images]
foc_slice=most_focused_image_index(images)

#images=[cv2.cvtColor(im, cv2.COLOR_BGR2RGB) for im in images]
# Parameters for border
border_color = [255, 0, 0]  # Red color in RGB
border_size = 1

def add_border(image, border_size, border_color):
    return cv2.copyMakeBorder(image, border_size, border_size, border_size, border_size, cv2.BORDER_CONSTANT, value=border_color)

# Adding border to the xth image
images[truth_slice] = add_border(images[truth_slice], border_size, border_color)
images[foc_slice] = add_border(images[foc_slice], border_size, [0,255,0])



# Create a figure with 7x7 subplots
row_size=7 if truth_slice%7==0 else 8
fig, axes = plt.subplots(1, row_size, figsize=(30, 30))

truth_display=True
# Plot each image
i=0
for ax in (axes.flat):
    if (i*7)<49:
        ax.imshow(images[i*7])
    if i*7 > truth_slice and truth_slice>(i-1)*7 and truth_display:
        ax.imshow(images[truth_slice])
        i-=1
        truth_display=False
    ax.axis('off')  # Hide the axes
    i+=1

# Display the grid
plt.tight_layout()
plt.show()

depth=cv2.imread(super_path+'merged_depth/'+image_type+'result_merged_depth_center.png')
depth=depth[patch[0]:patch[0]+32,patch[1]:patch[1]+32]
med=np.median(depth)
print(med)

max_depth = 100.0
min_depth = 0.2

med = (max_depth * min_depth) / (max_depth - (max_depth - min_depth) * (med / 255.0))

print(med*1000)
# Out:
# 2
# (229, 278)
# (504, 378, 3)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)
# 225.0
# 1674.8768472906388

# %%
fig, axes = plt.subplots(7, 7, figsize=(30, 30))

i=0
for ax in (axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes
    i+=1

# Display the grid
plt.tight_layout()
plt.show()

# %%
import os
import cv2

# Directory path where images are stored
path=super_path+'merged_depth/'+image_type

# Filename pattern to filter
filename_pattern = 'result_merged_depth_center.png'

image=cv2.imread(path+filename_pattern)
patch=(ground_truth[image_type[:-1]]['center'][pat][0],ground_truth[image_type[:-1]]['center'][pat][1])
image=image[patch[0]:patch[0]+32,patch[1]:patch[1]+32]

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Display the image
plt.imshow(image_rgb)
plt.axis('off')  # Hide the axis
plt.show()
